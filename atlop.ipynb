# %% [markdown]
# <a href="https://colab.research.google.com/github/passengeryjy/-review-atlop/blob/main/atlop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新段落

# %%
import os
path = "/content/apex-master"
os.chdir(path)
print(os.getcwd())
# Out:
# /content/apex-master

# %%
# !sh scripts/run_bert.sh
# Out:
# Traceback (most recent call last):
#   File "train.py", line 6, in <module>
#     from apex import amp
#   File "/usr/local/lib/python3.7/dist-packages/apex/__init__.py", line 13, in <module>
#     from pyramid.session import UnencryptedCookieSessionFactoryConfig
# ImportError: cannot import name 'UnencryptedCookieSessionFactoryConfig' from 'pyramid.session' (unknown location)

# %% [markdown]
# # 新段落

# %%
import os
path = "
os.chdir(path)
print(os.getcwd())
# Out:
# /content

# %%
# !sh scripts/run_bert.sh
# Out:
# Traceback (most recent call last):
#   File "train.py", line 6, in <module>
#     from apex import amp
#   File "/usr/local/lib/python3.7/dist-packages/apex/__init__.py", line 13, in <module>
#     from pyramid.session import UnencryptedCookieSessionFactoryConfig
# ImportError: cannot import name 'UnencryptedCookieSessionFactoryConfig' from 'pyramid.session' (unknown location)

# %%
# !pip install transformers==3.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 880 kB 42.6 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 48.2 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 46.1 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=af6da4868726ba957561ee284f19e964e035813b7d225d6cecd257bea0d49c4c
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 158 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 181 kB 64.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 157 kB 70.1 MB/s
# ...
#      |████████████████████████████████| 157 kB 75.0 MB/s
# ...
#      |████████████████████████████████| 157 kB 49.4 MB/s
# ...
#      |████████████████████████████████| 157 kB 71.3 MB/s
# ...
#      |████████████████████████████████| 157 kB 72.3 MB/s
# ...
#      |████████████████████████████████| 157 kB 71.3 MB/s
# ...
#      |████████████████████████████████| 157 kB 69.4 MB/s
# ...
#      |████████████████████████████████| 156 kB 73.9 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=665074af1ed1b15facc6f073d85e7a5ea70aaf40f7eb47fb1a011329d40a192f
# ...

# %%
# !sh scripts/run_bert.sh
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 1
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in /content/wandb/run-20220920_133133-2q5t5zhl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fast-moon-1
# wandb: ⭐️ View project at https://wandb.ai/passenger/DocRED
# wandb: 🚀 View run at https://wandb.ai/passenger/DocRED/runs/2q5t5zhl
# Example: 100% 3053/3053 [00:39<00:00, 77.59it/s]
# # of documents 3053.
# # of positive examples 35615.
# ...
